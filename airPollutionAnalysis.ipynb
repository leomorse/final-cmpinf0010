# %%
import pandas as pd

airPollutionCSV = pd.read_csv("airPollution.csv", index_col="_id")

query_mask = airPollutionCSV['CITY_NAME'] == "PITTSBURGH"

airPollutionPGH = airPollutionCSV[query_mask]

# %%
airPollutionPGH.head()
# Out:
#         TRI_FACILITY_ID   DOC_CTRL_NUM                     FACILITY_NAME  \
# _id
# 216217  15204PRTTSTABOR  1300140000694  PRUETT-SCHAFFER CHEMICAL CO INC.
# 216220  15233ZMMRM2020K  1300140055195                 E.E. ZIMMERMAN CO
# 216221  15233ZMMRM2020K  1300140055207                 E.E. ZIMMERMAN CO
# 216222  15233ZMMRM2020K  1300140055219                 E.E. ZIMMERMAN CO
# 216223  15233ZMMRM2020K  1300140055221                 E.E. ZIMMERMAN CO
#
#           STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE  \
# _id
# 216217  3327 STAFFORD ST  PITTSBURGH   ALLEGHENY                   42003
# 216220     2020 KNOTT ST  PITTSBURGH   ALLEGHENY                   42003
# 216221     2020 KNOTT ST  PITTSBURGH   ALLEGHENY                   42003
# 216222     2020 KNOTT ST  PITTSBURGH   ALLEGHENY                   42003
# 216223     2020 KNOTT ST  PITTSBURGH   ALLEGHENY                   42003
#
#        STATE_ABBR  ZIP_CODE  REGION  ...  NAICS_CODES INDUSTRY_CODE   SRS_ID  \
# _id                                  ...
# 216217         PA     15204       3  ...     325510.0           325  84970.0
# 216220         PA     15233       3  ...     424690.0          4246   7443.0
# 216221         PA     15233       3  ...     424690.0          4246   4283.0
# 216222         PA     15233       3  ...     424690.0          4246  16261.0
# 216223         PA     15233       3  ...     424690.0          4246  25452.0
#
#        PFAS_IND ENVIRONMENTAL_MEDIUM RELEASE_RANGE_CODE  REL_EST_AMT  \
# _id
# 216217        0            AIR STACK                NaN          NaN
# 216220        0            AIR STACK                NaN          NaN
# 216221        0            AIR STACK                NaN          NaN
# 216222        0            AIR STACK                NaN          NaN
# 216223        0            AIR STACK                NaN          NaN
#
#         RELEASE_NA  RELEASE_BASIS_EST_CODE TOTAL_RELEASE
# _id
# 216217           0                       E         390.0
# 216220           0                       C         133.0
# 216221           0                       C         640.0
# 216222           0                       C          29.0
# 216223           0                       C         242.0
#
# [5 rows x 41 columns]
